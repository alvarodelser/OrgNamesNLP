# %%
import json
from orgpackage.clusterembedder import embedder
from orgpackage.orchestrator import *
import pandas as pd

# %load_ext autoreload
# %autoreload 2

data = load_dataset('./data/wikidata_enriched_dataset.csv')
display(data)
# Out:
#                                          instance country  \
# 0       http://www.wikidata.org/entity/Q112984500    Q142
# 1          http://www.wikidata.org/entity/Q174928    Q142
# 2         http://www.wikidata.org/entity/Q1167843    Q142
# 3       http://www.wikidata.org/entity/Q119718461    Q142
# 4         http://www.wikidata.org/entity/Q1049782    Q142
# ...                                           ...     ...
# 182532  http://www.wikidata.org/entity/Q113813349     Q55
# 182533  http://www.wikidata.org/entity/Q116194320     Q55
# 182534  http://www.wikidata.org/entity/Q116353302     Q55
# 182535  http://www.wikidata.org/entity/Q130889779     Q55
# 182536  http://www.wikidata.org/entity/Q131348769     Q55
#
#                                       names  \
# 0                    Foyer Logement de Guer
# 1                       Saint-André-d'Allas
# 2                                  Ménonval
# 3       54e régiment d'artillerie coloniale
# 4                     Han-devant-Pierrepont
# ...                                     ...
# 182532                       Dalton College
# 182533             Wings Niekée Agoraschool
# 182534                    Sweelinck College
# 182535                    Eijkhagen College
# 182536                     Merewade College
#
#                                          class_ids  \
# 0       [http://www.wikidata.org/entity/Q30114662]
# 1         [http://www.wikidata.org/entity/Q484170]
# 2         [http://www.wikidata.org/entity/Q484170]
# 3         [http://www.wikidata.org/entity/Q176799]
# 4         [http://www.wikidata.org/entity/Q484170]
# ...                                            ...
# 182532    [http://www.wikidata.org/entity/Q159334]
# 182533    [http://www.wikidata.org/entity/Q159334]
# 182534    [http://www.wikidata.org/entity/Q159334]
# 182535    [http://www.wikidata.org/entity/Q159334]
# 182536    [http://www.wikidata.org/entity/Q159334]
#
#                                                   classes  hospital  \
# 0       [accommodation facility for dependent elderly ...         0
# 1                                     [commune of France]         0
# 2                                     [commune of France]         0
# 3                                         [military unit]         0
# 4                                     [commune of France]         0
# ...                                                   ...       ...
# 182532                                 [secondary school]         0
# 182533                                 [secondary school]         0
# 182534                                 [secondary school]         0
# 182535                                 [secondary school]         0
# 182536                                 [secondary school]         0
#
#         university_hospital  local_government  primary_school  \
# 0                         0                 0               0
# 1                         0                 0               0
# 2                         0                 0               0
# 3                         0                 0               0
# 4                         0                 0               0
# ...                     ...               ...             ...
# 182532                    0                 0               0
# 182533                    0                 0               0
# 182534                    0                 0               0
# 182535                    0                 0               0
# 182536                    0                 0               0
#
#         secondary_school
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 182532                 1
# 182533                 1
# 182534                 1
# 182535                 1
# 182536                 1
#
# [182537 rows x 10 columns]

# %%
embedder(data)
# Out:
# /Users/alvarodelser/Projects/Organization Names Comprehension/orgpackage/clusterembedder.py:38: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_saved = pd.read_csv(save_path)
# All embeddings for multilingual-e5 already exist.
# Loading model: qwen
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]
# Generating embeddings for qwen starting from index 1632
# Generating embeddings for qwen:  23%|██▎       | 1298/5654 [20:21:11<68:43:29, 56.80s/it]

# %%
emb = pd.read_csv('./results/embeddings.csv')
display(emb)
# Out:
# /var/folders/q_/kvl1vqd97qq_hn08p839948m0000gn/T/ipykernel_30289/2412242766.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   emb = pd.read_csv('./results/embeddings.csv')
#                                          instance country  \
# 0       http://www.wikidata.org/entity/Q112984500    Q142
# 1          http://www.wikidata.org/entity/Q174928    Q142
# 2         http://www.wikidata.org/entity/Q1167843    Q142
# 3       http://www.wikidata.org/entity/Q119718461    Q142
# 4         http://www.wikidata.org/entity/Q1049782    Q142
# ...                                           ...     ...
# 182532  http://www.wikidata.org/entity/Q113813349     Q55
# 182533  http://www.wikidata.org/entity/Q116194320     Q55
# 182534  http://www.wikidata.org/entity/Q116353302     Q55
# 182535  http://www.wikidata.org/entity/Q130889779     Q55
# 182536  http://www.wikidata.org/entity/Q131348769     Q55
#
#                                       names  \
# 0                    Foyer Logement de Guer
# 1                       Saint-André-d'Allas
# 2                                  Ménonval
# 3       54e régiment d'artillerie coloniale
# 4                     Han-devant-Pierrepont
# ...                                     ...
# 182532                       Dalton College
# 182533             Wings Niekée Agoraschool
# 182534                    Sweelinck College
# 182535                    Eijkhagen College
# 182536                     Merewade College
#
#                                            class_ids  \
# 0       ['http://www.wikidata.org/entity/Q30114662']
# 1         ['http://www.wikidata.org/entity/Q484170']
# 2         ['http://www.wikidata.org/entity/Q484170']
# 3         ['http://www.wikidata.org/entity/Q176799']
# 4         ['http://www.wikidata.org/entity/Q484170']
# ...                                              ...
# 182532    ['http://www.wikidata.org/entity/Q159334']
# 182533    ['http://www.wikidata.org/entity/Q159334']
# 182534    ['http://www.wikidata.org/entity/Q159334']
# 182535    ['http://www.wikidata.org/entity/Q159334']
# 182536    ['http://www.wikidata.org/entity/Q159334']
#
#                                                   classes  hospital  \
# 0       ['accommodation facility for dependent elderly...         0
# 1                                   ['commune of France']         0
# 2                                   ['commune of France']         0
# 3                                       ['military unit']         0
# 4                                   ['commune of France']         0
# ...                                                   ...       ...
# 182532                               ['secondary school']         0
# 182533                               ['secondary school']         0
# 182534                               ['secondary school']         0
# 182535                               ['secondary school']         0
# 182536                               ['secondary school']         0
#
#         university_hospital  local_government  primary_school  \
# 0                         0                 0               0
# 1                         0                 0               0
# 2                         0                 0               0
# 3                         0                 0               0
# 4                         0                 0               0
# ...                     ...               ...             ...
# 182532                    0                 0               0
# 182533                    0                 0               0
# 182534                    0                 0               0
# 182535                    0                 0               0
# 182536                    0                 0               0
#
#         secondary_school                          multilingual-e5_embedding  \
# 0                      0  [0.02068309299647808, 0.052959855645895004, 0....
# 1                      0  [0.01896124705672264, 0.03736007213592529, 0.0...
# 2                      0  [0.011003664694726467, 0.048440806567668915, 0...
# 3                      0  [0.010568561963737011, 0.044072724878787994, 0...
# 4                      0  [0.01298102829605341, 0.0453668050467968, 0.01...
# ...                  ...                                                ...
# 182532                 1  [0.009343275800347328, 0.04355081915855408, 0....
# 182533                 1  [0.015205192379653454, 0.03255501389503479, 0....
# 182534                 1  [-0.00471335556358099, 0.03512212261557579, -0...
# 182535                 1  [0.007862389087677002, 0.026225632056593895, 0...
# 182536                 1  [0.0026797116734087467, 0.03667297214269638, 0...
#
#                                            qwen_embedding
# 0       [-0.019149670377373695, -0.00606427202001214, ...
# 1       [-0.003527347231283784, 0.004488314501941204, ...
# 2       [-0.009620183147490025, 0.0053380862809717655,...
# 3       [-0.02173159271478653, -0.007126019801944494, ...
# 4       [-0.012741331942379475, -0.008677946403622627,...
# ...                                                   ...
# 182532                                                NaN
# 182533                                                NaN
# 182534                                                NaN
# 182535                                                NaN
# 182536                                                NaN
#
# [182537 rows x 12 columns]
